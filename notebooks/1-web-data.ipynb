# %% [markdown]
# # Broadband Access

# %% [markdown]
# **Notebook: 1-web-data**

# %% [markdown]
# # Abstract

# %% [markdown]
# **Purpose:**
# This notebook (intended for a technical audience) pursues a preliminary understanding of data sources and variable labels relevant for exploring disparities in broadband Internet access across lower-level geographies and demographics.
#
# **Acknowledgments:**
# Data source: U.S. Census Bureau, 2019 American Community Survey 1-Year Estimates (https://data.census.gov/cedsci/table?q=broadband&g=0400000US51.050000&y=2019&d=ACS%201-Year%20Estimates%20Data%20Profiles&tid=ACSDP1Y2019.DP02&hidePreview=false)

# %% [markdown]
# # Scope (notebook)

# %% [markdown]
#  - import libraries
#  - read American Community Survey (ACS) CSV data into Pandas
#  - inspect data for task-relevant variables
#  - subset data
#  - serialize objects for further study

# %% [markdown]
# # Setup

# %%
# importing packages
import os
import pandas as pd

# %% [markdown]
# # Obtain

# %%
# instantiating the data file as a dataframe
data = pd.read_csv('../data/ACSDP1Y2019.DP02_data_with_overlays_2020-11-07T164043.csv')

# %%
# instantiating the metadata file as a dataframe
metadata = pd.read_csv('../data/ACSDP1Y2019.DP02_metadata_2020-11-07T164043.csv')

# %%
# viewing dataset info
data.info(), data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Columns: 614 entries, GEO_ID to DP02_0153PM
# dtypes: object(614)
# memory usage: 148.8+ KB
# (None, (31, 614))

# %% [markdown]
# There are 31 rows and 614 columns in this dataset.

# %%
# viewing first rows
data.head()
# Out:
#            GEO_ID                        NAME  \
# 0              id        Geographic Area Name
# 1  0500000US51003  Albemarle County, Virginia
# 2  0500000US51013  Arlington County, Virginia
# 3  0500000US51015    Augusta County, Virginia
# 4  0500000US51019    Bedford County, Virginia
#
#                                        DP02_0001E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                           43754
# 2                                          111887
# 3                                           29951
# 4                                           31390
#
#                                           DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                               1134
# 2                                               1847
# 3                                               1333
# 4                                               1264
#
#                                      DP02_0001PE  \
# 0  Percent!!HOUSEHOLDS BY TYPE!!Total households
# 1                                          43754
# 2                                         111887
# 3                                          29951
# 4                                          31390
#
#                                          DP02_0001PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           DP02_0002E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                              22481
# 2                                              41865
# 3                                              17168
# 4                                              18059
#
#                                           DP02_0002M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                               1665
# 2                                               2320
# 3                                               1482
# 4                                               1613
#
#                                          DP02_0002PE  \
# 0  Percent!!HOUSEHOLDS BY TYPE!!Total households!...
# 1                                               51.4
# 2                                               37.4
# 3                                               57.3
# 4                                               57.5
#
#                                          DP02_0002PM  ...  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...  ...
# 1                                                3.5  ...
# 2                                                2.0  ...
# 3                                                4.4  ...
# 4                                                4.7  ...
#
#                                          DP02_0151PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                              43754
# 2                                             111887
# 3                                              29951
# 4                                              31390
#
#                                          DP02_0151PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           DP02_0152E  \
# 0  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1                                              40025
# 2                                             107630
# 3                                              27446
# 4                                              27730
#
#                                           DP02_0152M  \
# 0  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 1                                               1685
# 2                                               2362
# 3                                               1524
# 4                                               1641
#
#                                          DP02_0152PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                               91.5
# 2                                               96.2
# 3                                               91.6
# 4                                               88.3
#
#                                          DP02_0152PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                2.8
# 2                                                1.3
# 3                                                2.6
# 4                                                3.0
#
#                                           DP02_0153E  \
# 0  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1                                              38057
# 2                                             103460
# 3                                              25807
# 4                                              24229
#
#                                           DP02_0153M  \
# 0  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 1                                               1723
# 2                                               2365
# 3                                               1681
# 4                                               1757
#
#                                          DP02_0153PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                               87.0
# 2                                               92.5
# 3                                               86.2
# 4                                               77.2
#
#                                          DP02_0153PM
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                                                3.0
# 2                                                1.4
# 3                                                3.8
# 4                                                4.3
#
# [5 rows x 614 columns]

# %%
# viewing last rows
data.tail()
# Out:
#             GEO_ID                           NAME DP02_0001E DP02_0001M  \
# 26  0500000US51740      Portsmouth city, Virginia      36089       1133
# 27  0500000US51760        Richmond city, Virginia      89878       2207
# 28  0500000US51770         Roanoke city, Virginia      40810       1405
# 29  0500000US51800         Suffolk city, Virginia      34597       1038
# 30  0500000US51810  Virginia Beach city, Virginia     175029       2072
#
#    DP02_0001PE DP02_0001PM DP02_0002E DP02_0002M DP02_0002PE DP02_0002PM  ...  \
# 26       36089         (X)      11652       1672        32.3         4.4  ...
# 27       89878         (X)      24807       1897        27.6         2.2  ...
# 28       40810         (X)      12425       1674        30.4         3.9  ...
# 29       34597         (X)      17742       1329        51.3         4.1  ...
# 30      175029         (X)      89905       3624        51.4         1.9  ...
#
#    DP02_0151PE DP02_0151PM DP02_0152E DP02_0152M DP02_0152PE DP02_0152PM  \
# 26       36089         (X)      33571       1227        93.0         1.7
# 27       89878         (X)      81418       2656        90.6         2.0
# 28       40810         (X)      35580       1779        87.2         3.2
# 29       34597         (X)      32162       1204        93.0         2.3
# 30      175029         (X)     169091       2530        96.6         0.9
#
#    DP02_0153E DP02_0153M DP02_0153PE DP02_0153PM
# 26      31644       1221        87.7         2.3
# 27      73754       2573        82.1         2.4
# 28      32035       1907        78.5         4.3
# 29      29058       1309        84.0         3.3
# 30     162381       2694        92.8         1.1
#
# [5 rows x 614 columns]

# %% [markdown]
# Each row appears to represent a county or county-equivalent. There are 133 such geographies in Virginia, so only a portion of those are included in the 1-year estimates.

# %% [markdown]
# We see that most of the column lables are coded.

# %% [markdown]
# The first row appears to contain descriptive metadata. For example, in the column labeled `DP02_0001E`,  "Estimate!!HOUSEHOLDS BY TYPE!!Total households" is the first entry. Let's verify that this matches our `metadata` file.

# %%
# viewing first rows from metadata
metadata.head()
# Out:
#         GEO_ID                                                 id
# 0         NAME                               Geographic Area Name
# 1   DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 2   DP02_0001M  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 3  DP02_0001PE      Percent!!HOUSEHOLDS BY TYPE!!Total households
# 4  DP02_0001PM  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...

# %% [markdown]
# The entries match. Let's remove the 0th row from `data` and find `metadata` columns containing the string "broadband".

# %%
# deleting the 0th row
update_data = data.drop([data.index[0]]) 

# resetting the index to increment from 0
update_data.reset_index(drop=True, inplace=True)

update_data
# Out:
#             GEO_ID                             NAME DP02_0001E DP02_0001M  \
# 0   0500000US51003       Albemarle County, Virginia      43754       1134
# 1   0500000US51013       Arlington County, Virginia     111887       1847
# 2   0500000US51015         Augusta County, Virginia      29951       1333
# 3   0500000US51019         Bedford County, Virginia      31390       1264
# 4   0500000US51041    Chesterfield County, Virginia     128920       1764
# 5   0500000US51059         Fairfax County, Virginia     400186       2978
# 6   0500000US51061        Fauquier County, Virginia      24270       1052
# 7   0500000US51069       Frederick County, Virginia      32010       1398
# 8   0500000US51085         Hanover County, Virginia      39521       1078
# 9   0500000US51087         Henrico County, Virginia     130591       1988
# 10  0500000US51095      James City County, Virginia      30262       1513
# 11  0500000US51107         Loudoun County, Virginia     133750       1935
# 12  0500000US51121      Montgomery County, Virginia      36244       1423
# 13  0500000US51153  Prince William County, Virginia     143508       1907
# 14  0500000US51161         Roanoke County, Virginia      37506       1472
# 15  0500000US51165      Rockingham County, Virginia      30462       1157
# 16  0500000US51177    Spotsylvania County, Virginia      46427       1134
# 17  0500000US51179        Stafford County, Virginia      48092       1304
# 18  0500000US51199            York County, Virginia      26008        921
# 19  0500000US51510        Alexandria city, Virginia      71005       1523
# 20  0500000US51550        Chesapeake city, Virginia      86878       1764
# 21  0500000US51650           Hampton city, Virginia      55633       1442
# 22  0500000US51680         Lynchburg city, Virginia      28950       1238
# 23  0500000US51700      Newport News city, Virginia      70918       2279
# 24  0500000US51710           Norfolk city, Virginia      88387       2248
# 25  0500000US51740        Portsmouth city, Virginia      36089       1133
# 26  0500000US51760          Richmond city, Virginia      89878       2207
# 27  0500000US51770           Roanoke city, Virginia      40810       1405
# 28  0500000US51800           Suffolk city, Virginia      34597       1038
# 29  0500000US51810    Virginia Beach city, Virginia     175029       2072
#
#    DP02_0001PE DP02_0001PM DP02_0002E DP02_0002M DP02_0002PE DP02_0002PM  ...  \
# 0        43754         (X)      22481       1665        51.4         3.5  ...
# 1       111887         (X)      41865       2320        37.4         2.0  ...
# 2        29951         (X)      17168       1482        57.3         4.4  ...
# 3        31390         (X)      18059       1613        57.5         4.7  ...
# 4       128920         (X)      70225       2556        54.5         2.0  ...
# 5       400186         (X)     230047       4643        57.5         1.1  ...
# 6        24270         (X)      14563       1297        60.0         4.9  ...
# 7        32010         (X)      19368       1776        60.5         5.1  ...
# 8        39521         (X)      24537       1840        62.1         4.3  ...
# 9       130591         (X)      58703       3033        45.0         2.4  ...
# 10       30262         (X)      17490       1546        57.8         4.2  ...
# 11      133750         (X)      90154       3127        67.4         2.2  ...
# 12       36244         (X)      16630       1706        45.9         4.5  ...
# 13      143508         (X)      85448       3799        59.5         2.4  ...
# 14       37506         (X)      19782       1646        52.7         4.5  ...
# 15       30462         (X)      18095       1375        59.4         3.9  ...
# 16       46427         (X)      26008       1757        56.0         3.5  ...
# 17       48092         (X)      31349       1946        65.2         3.8  ...
# 18       26008         (X)      14963       1293        57.5         4.7  ...
# 19       71005         (X)      25522       1952        35.9         2.6  ...
# 20       86878         (X)      47147       2379        54.3         2.8  ...
# 21       55633         (X)      21693       2165        39.0         3.9  ...
# 22       28950         (X)      11739       1754        40.5         5.8  ...
# 23       70918         (X)      24351       1861        34.3         2.4  ...
# 24       88387         (X)      29431       2199        33.3         2.4  ...
# 25       36089         (X)      11652       1672        32.3         4.4  ...
# 26       89878         (X)      24807       1897        27.6         2.2  ...
# 27       40810         (X)      12425       1674        30.4         3.9  ...
# 28       34597         (X)      17742       1329        51.3         4.1  ...
# 29      175029         (X)      89905       3624        51.4         1.9  ...
#
#    DP02_0151PE DP02_0151PM DP02_0152E DP02_0152M DP02_0152PE DP02_0152PM  \
# 0        43754         (X)      40025       1685        91.5         2.8
# 1       111887         (X)     107630       2362        96.2         1.3
# 2        29951         (X)      27446       1524        91.6         2.6
# 3        31390         (X)      27730       1641        88.3         3.0
# 4       128920         (X)     122624       2141        95.1         0.9
# 5       400186         (X)     391570       3422        97.8         0.4
# 6        24270         (X)      22328       1207        92.0         2.4
# 7        32010         (X)      29550       1595        92.3         2.7
# 8        39521         (X)      36585       1387        92.6         2.3
# 9       130591         (X)     120898       2574        92.6         1.4
# 10       30262         (X)      28878       1607        95.4         2.4
# 11      133750         (X)     131399       2120        98.2         0.5
# 12       36244         (X)      34572       1514        95.4         1.6
# 13      143508         (X)     140840       2171        98.1         0.6
# 14       37506         (X)      34375       1544        91.7         2.6
# 15       30462         (X)      27390       1380        89.9         2.5
# 16       46427         (X)      44255       1271        95.3         1.4
# 17       48092         (X)      46787       1398        97.3         1.2
# 18       26008         (X)      24842       1032        95.5         2.2
# 19       71005         (X)      68106       1887        95.9         1.3
# 20       86878         (X)      84048       1892        96.7         0.9
# 21       55633         (X)      52008       1663        93.5         1.9
# 22       28950         (X)      27940       1283        96.5         1.4
# 23       70918         (X)      66443       2323        93.7         1.5
# 24       88387         (X)      81678       2584        92.4         1.2
# 25       36089         (X)      33571       1227        93.0         1.7
# 26       89878         (X)      81418       2656        90.6         2.0
# 27       40810         (X)      35580       1779        87.2         3.2
# 28       34597         (X)      32162       1204        93.0         2.3
# 29      175029         (X)     169091       2530        96.6         0.9
#
#    DP02_0153E DP02_0153M DP02_0153PE DP02_0153PM
# 0       38057       1723        87.0         3.0
# 1      103460       2365        92.5         1.4
# 2       25807       1681        86.2         3.8
# 3       24229       1757        77.2         4.3
# 4      115443       2812        89.5         1.7
# 5      382803       3539        95.7         0.6
# 6       21241       1293        87.5         3.0
# 7       26805       1677        83.7         3.1
# 8       33859       1666        85.7         3.2
# 9      112672       2952        86.3         1.8
# 10      27223       1677        90.0         3.5
# 11     127625       2436        95.4         1.2
# 12      33056       1661        91.2         2.6
# 13     137524       2159        95.8         0.8
# 14      32685       1696        87.1         3.0
# 15      24822       1670        81.5         3.7
# 16      42465       1419        91.5         2.1
# 17      45469       1466        94.5         1.8
# 18      23559       1098        90.6         2.7
# 19      65428       1931        92.1         1.6
# 20      79413       2063        91.4         1.8
# 21      47767       1933        85.9         2.5
# 22      26975       1370        93.2         2.2
# 23      60865       2938        85.8         2.6
# 24      73239       2546        82.9         1.9
# 25      31644       1221        87.7         2.3
# 26      73754       2573        82.1         2.4
# 27      32035       1907        78.5         4.3
# 28      29058       1309        84.0         3.3
# 29     162381       2694        92.8         1.1
#
# [30 rows x 614 columns]

# %%
# searching the term "broadband" in metadata's `id` column
filtered_meta = metadata[metadata['id'].str.contains("broadband")]
filtered_meta
# Out:
#           GEO_ID                                                 id
# 609   DP02_0153E  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 610   DP02_0153M  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 611  DP02_0153PE  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 612  DP02_0153PM  Percent Margin of Error!!COMPUTERS AND INTERNE...

# %% [markdown]
# The filtered dataframe's `GEO_ID` shows us which `data` labels are relevant to broadband.
#
# Let's list the labels and inspect the relevant rows from `data`..

# %%
# listing the filtered `GEO_ID` column labels
broadband_vars = filtered_meta['GEO_ID'].tolist()

# viewing the list of filtered labels
broadband_vars
# Out:
# ['DP02_0153E', 'DP02_0153M', 'DP02_0153PE', 'DP02_0153PM']

# %%
# subset `data` to include only columns with labels in `broadband_vars`
update_data[broadband_vars]
# Out:
#    DP02_0153E DP02_0153M DP02_0153PE DP02_0153PM
# 0       38057       1723        87.0         3.0
# 1      103460       2365        92.5         1.4
# 2       25807       1681        86.2         3.8
# 3       24229       1757        77.2         4.3
# 4      115443       2812        89.5         1.7
# 5      382803       3539        95.7         0.6
# 6       21241       1293        87.5         3.0
# 7       26805       1677        83.7         3.1
# 8       33859       1666        85.7         3.2
# 9      112672       2952        86.3         1.8
# 10      27223       1677        90.0         3.5
# 11     127625       2436        95.4         1.2
# 12      33056       1661        91.2         2.6
# 13     137524       2159        95.8         0.8
# 14      32685       1696        87.1         3.0
# 15      24822       1670        81.5         3.7
# 16      42465       1419        91.5         2.1
# 17      45469       1466        94.5         1.8
# 18      23559       1098        90.6         2.7
# 19      65428       1931        92.1         1.6
# 20      79413       2063        91.4         1.8
# 21      47767       1933        85.9         2.5
# 22      26975       1370        93.2         2.2
# 23      60865       2938        85.8         2.6
# 24      73239       2546        82.9         1.9
# 25      31644       1221        87.7         2.3
# 26      73754       2573        82.1         2.4
# 27      32035       1907        78.5         4.3
# 28      29058       1309        84.0         3.3
# 29     162381       2694        92.8         1.1

# %% [markdown]
# For reference, we can create a dictionary from `metadata` to more easily reference descriptions for the columns in `data`. This will be useful for identifying columns that may interest us for analysis.

# %%
# creating a metadata dictionary
metadata_dict = metadata.set_index('GEO_ID').T.to_dict('list')

# %%
metadata_dict
# Out:
# {'NAME': ['Geographic Area Name'],
#  'DP02_0001E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households'],
#  'DP02_0001M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households'],
#  'DP02_0001PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households'],
#  'DP02_0001PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households'],
#  'DP02_0002E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family'],
#  'DP02_0002M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family'],
#  'DP02_0002PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family'],
#  'DP02_0002PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family'],
#  'DP02_0003E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family!!With own children of the householder under 18 years'],
#  'DP02_0003M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family!!With own children of the householder under 18 years'],
#  'DP02_0003PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family!!With own children of the householder under 18 years'],
#  'DP02_0003PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple family!!With own children of the householder under 18 years'],
#  'DP02_0004E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'],
#  'DP02_0004M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'],
#  'DP02_0004PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'],
#  'DP02_0004PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household'],
#  'DP02_0005E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children of the householder under 18 years'],
#  'DP02_0005M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children of the householder under 18 years'],
#  'DP02_0005PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children of the householder under 18 years'],
#  'DP02_0005PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Cohabiting couple household!!With own children of the householder under 18 years'],
#  'DP02_0006E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present'],
#  'DP02_0006M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present'],
#  'DP02_0006PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present'],
#  'DP02_0006PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present'],
#  'DP02_0007E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0007M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0007PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0007PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0008E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0008M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0008PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0008PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0009E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0009M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0009PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0009PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Male householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0010E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present'],
#  'DP02_0010M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present'],
#  'DP02_0010PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present'],
#  'DP02_0010PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present'],
#  'DP02_0011E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0011M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0011PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0011PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!With own children of the householder under 18 years'],
#  'DP02_0012E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0012M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0012PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0012PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone'],
#  'DP02_0013E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0013M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0013PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0013PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Female householder, no spouse/partner present!!Householder living alone!!65 years and over'],
#  'DP02_0014E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people under 18 years'],
#  'DP02_0014M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people under 18 years'],
#  'DP02_0014PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people under 18 years'],
#  'DP02_0014PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people under 18 years'],
#  'DP02_0015E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people 65 years and over'],
#  'DP02_0015M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people 65 years and over'],
#  'DP02_0015PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people 65 years and over'],
#  'DP02_0015PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Households with one or more people 65 years and over'],
#  'DP02_0016E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Average household size'],
#  'DP02_0016M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Average household size'],
#  'DP02_0016PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Average household size'],
#  'DP02_0016PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Average household size'],
#  'DP02_0017E': ['Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Average family size'],
#  'DP02_0017M': ['Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Average family size'],
#  'DP02_0017PE': ['Percent!!HOUSEHOLDS BY TYPE!!Total households!!Average family size'],
#  'DP02_0017PM': ['Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households!!Average family size'],
#  'DP02_0018E': ['Estimate!!RELATIONSHIP!!Population in households'],
#  'DP02_0018M': ['Margin of Error!!RELATIONSHIP!!Population in households'],
#  'DP02_0018PE': ['Percent!!RELATIONSHIP!!Population in households'],
#  'DP02_0018PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households'],
#  'DP02_0019E': ['Estimate!!RELATIONSHIP!!Population in households!!Householder'],
#  'DP02_0019M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Householder'],
#  'DP02_0019PE': ['Percent!!RELATIONSHIP!!Population in households!!Householder'],
#  'DP02_0019PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Householder'],
#  'DP02_0020E': ['Estimate!!RELATIONSHIP!!Population in households!!Spouse'],
#  'DP02_0020M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Spouse'],
#  'DP02_0020PE': ['Percent!!RELATIONSHIP!!Population in households!!Spouse'],
#  'DP02_0020PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Spouse'],
#  'DP02_0021E': ['Estimate!!RELATIONSHIP!!Population in households!!Unmarried partner'],
#  'DP02_0021M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Unmarried partner'],
#  'DP02_0021PE': ['Percent!!RELATIONSHIP!!Population in households!!Unmarried partner'],
#  'DP02_0021PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Unmarried partner'],
#  'DP02_0022E': ['Estimate!!RELATIONSHIP!!Population in households!!Child'],
#  'DP02_0022M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Child'],
#  'DP02_0022PE': ['Percent!!RELATIONSHIP!!Population in households!!Child'],
#  'DP02_0022PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Child'],
#  'DP02_0023E': ['Estimate!!RELATIONSHIP!!Population in households!!Other relatives'],
#  'DP02_0023M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Other relatives'],
#  'DP02_0023PE': ['Percent!!RELATIONSHIP!!Population in households!!Other relatives'],
#  'DP02_0023PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Other relatives'],
#  'DP02_0024E': ['Estimate!!RELATIONSHIP!!Population in households!!Other nonrelatives'],
#  'DP02_0024M': ['Margin of Error!!RELATIONSHIP!!Population in households!!Other nonrelatives'],
#  'DP02_0024PE': ['Percent!!RELATIONSHIP!!Population in households!!Other nonrelatives'],
#  'DP02_0024PM': ['Percent Margin of Error!!RELATIONSHIP!!Population in households!!Other nonrelatives'],
#  'DP02_0025E': ['Estimate!!MARITAL STATUS!!Males 15 years and over'],
#  'DP02_0025M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over'],
#  'DP02_0025PE': ['Percent!!MARITAL STATUS!!Males 15 years and over'],
#  'DP02_0025PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over'],
#  'DP02_0026E': ['Estimate!!MARITAL STATUS!!Males 15 years and over!!Never married'],
#  'DP02_0026M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Never married'],
#  'DP02_0026PE': ['Percent!!MARITAL STATUS!!Males 15 years and over!!Never married'],
#  'DP02_0026PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Never married'],
#  'DP02_0027E': ['Estimate!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated'],
#  'DP02_0027M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated'],
#  'DP02_0027PE': ['Percent!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated'],
#  'DP02_0027PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Now married, except separated'],
#  'DP02_0028E': ['Estimate!!MARITAL STATUS!!Males 15 years and over!!Separated'],
#  'DP02_0028M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Separated'],
#  'DP02_0028PE': ['Percent!!MARITAL STATUS!!Males 15 years and over!!Separated'],
#  'DP02_0028PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Separated'],
#  'DP02_0029E': ['Estimate!!MARITAL STATUS!!Males 15 years and over!!Widowed'],
#  'DP02_0029M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Widowed'],
#  'DP02_0029PE': ['Percent!!MARITAL STATUS!!Males 15 years and over!!Widowed'],
#  'DP02_0029PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Widowed'],
#  'DP02_0030E': ['Estimate!!MARITAL STATUS!!Males 15 years and over!!Divorced'],
#  'DP02_0030M': ['Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Divorced'],
#  'DP02_0030PE': ['Percent!!MARITAL STATUS!!Males 15 years and over!!Divorced'],
#  'DP02_0030PM': ['Percent Margin of Error!!MARITAL STATUS!!Males 15 years and over!!Divorced'],
#  'DP02_0031E': ['Estimate!!MARITAL STATUS!!Females 15 years and over'],
#  'DP02_0031M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over'],
#  'DP02_0031PE': ['Percent!!MARITAL STATUS!!Females 15 years and over'],
#  'DP02_0031PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over'],
#  'DP02_0032E': ['Estimate!!MARITAL STATUS!!Females 15 years and over!!Never married'],
#  'DP02_0032M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Never married'],
#  'DP02_0032PE': ['Percent!!MARITAL STATUS!!Females 15 years and over!!Never married'],
#  'DP02_0032PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Never married'],
#  'DP02_0033E': ['Estimate!!MARITAL STATUS!!Females 15 years and over!!Now married, except separated'],
#  'DP02_0033M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Now married, except separated'],
#  'DP02_0033PE': ['Percent!!MARITAL STATUS!!Females 15 years and over!!Now married, except separated'],
#  'DP02_0033PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Now married, except separated'],
#  'DP02_0034E': ['Estimate!!MARITAL STATUS!!Females 15 years and over!!Separated'],
#  'DP02_0034M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Separated'],
#  'DP02_0034PE': ['Percent!!MARITAL STATUS!!Females 15 years and over!!Separated'],
#  'DP02_0034PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Separated'],
#  'DP02_0035E': ['Estimate!!MARITAL STATUS!!Females 15 years and over!!Widowed'],
#  'DP02_0035M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Widowed'],
#  'DP02_0035PE': ['Percent!!MARITAL STATUS!!Females 15 years and over!!Widowed'],
#  'DP02_0035PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Widowed'],
#  'DP02_0036E': ['Estimate!!MARITAL STATUS!!Females 15 years and over!!Divorced'],
#  'DP02_0036M': ['Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Divorced'],
#  'DP02_0036PE': ['Percent!!MARITAL STATUS!!Females 15 years and over!!Divorced'],
#  'DP02_0036PM': ['Percent Margin of Error!!MARITAL STATUS!!Females 15 years and over!!Divorced'],
#  'DP02_0037E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months'],
#  'DP02_0037M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months'],
#  'DP02_0037PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months'],
#  'DP02_0037PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months'],
#  'DP02_0038E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)'],
#  'DP02_0038M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)'],
#  'DP02_0038PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)'],
#  'DP02_0038PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)'],
#  'DP02_0039E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)!!Per 1,000 unmarried women'],
#  'DP02_0039M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)!!Per 1,000 unmarried women'],
#  'DP02_0039PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)!!Per 1,000 unmarried women'],
#  'DP02_0039PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Unmarried women (widowed, divorced, and never married)!!Per 1,000 unmarried women'],
#  'DP02_0040E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old'],
#  'DP02_0040M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old'],
#  'DP02_0040PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old'],
#  'DP02_0040PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 50 years old'],
#  'DP02_0041E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old'],
#  'DP02_0041M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old'],
#  'DP02_0041PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old'],
#  'DP02_0041PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 15 to 19 years old'],
#  'DP02_0042E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 20 to 34 years old'],
#  'DP02_0042M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 20 to 34 years old'],
#  'DP02_0042PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 20 to 34 years old'],
#  'DP02_0042PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 20 to 34 years old'],
#  'DP02_0043E': ['Estimate!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 35 to 50 years old'],
#  'DP02_0043M': ['Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 35 to 50 years old'],
#  'DP02_0043PE': ['Percent!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 35 to 50 years old'],
#  'DP02_0043PM': ['Percent Margin of Error!!FERTILITY!!Number of women 15 to 50 years old who had a birth in the past 12 months!!Per 1,000 women 35 to 50 years old'],
#  'DP02_0044E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years'],
#  'DP02_0044M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years'],
#  'DP02_0044PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years'],
#  'DP02_0044PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years'],
#  'DP02_0045E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren'],
#  'DP02_0045M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren'],
#  'DP02_0045PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren'],
#  'DP02_0045PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Grandparents responsible for grandchildren'],
#  'DP02_0046E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year'],
#  'DP02_0046M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year'],
#  'DP02_0046PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year'],
#  'DP02_0046PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!Less than 1 year'],
#  'DP02_0047E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years'],
#  'DP02_0047M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years'],
#  'DP02_0047PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years'],
#  'DP02_0047PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!1 or 2 years'],
#  'DP02_0048E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!3 or 4 years'],
#  'DP02_0048M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!3 or 4 years'],
#  'DP02_0048PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!3 or 4 years'],
#  'DP02_0048PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!3 or 4 years'],
#  'DP02_0049E': ['Estimate!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years'],
#  'DP02_0049M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years'],
#  'DP02_0049PE': ['Percent!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years'],
#  'DP02_0049PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents living with own grandchildren under 18 years!!Years responsible for grandchildren!!5 or more years'],
#  'DP02_0050E': ['Estimate!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years'],
#  'DP02_0050M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years'],
#  'DP02_0050PE': ['Percent!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years'],
#  'DP02_0050PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years'],
#  'DP02_0051E': ['Estimate!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female'],
#  'DP02_0051M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female'],
#  'DP02_0051PE': ['Percent!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female'],
#  'DP02_0051PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are female'],
#  'DP02_0052E': ['Estimate!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married'],
#  'DP02_0052M': ['Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married'],
#  'DP02_0052PE': ['Percent!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married'],
#  'DP02_0052PM': ['Percent Margin of Error!!GRANDPARENTS!!Number of grandparents responsible for own grandchildren under 18 years!!Who are married'],
#  'DP02_0053E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school'],
#  'DP02_0053M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school'],
#  'DP02_0053PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school'],
#  'DP02_0053PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school'],
#  'DP02_0054E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool'],
#  'DP02_0054M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool'],
#  'DP02_0054PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool'],
#  'DP02_0054PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school, preschool'],
#  'DP02_0055E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten'],
#  'DP02_0055M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten'],
#  'DP02_0055PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten'],
#  'DP02_0055PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten'],
#  'DP02_0056E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)'],
#  'DP02_0056M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)'],
#  'DP02_0056PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)'],
#  'DP02_0056PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)'],
#  'DP02_0057E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)'],
#  'DP02_0057M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)'],
#  'DP02_0057PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)'],
#  'DP02_0057PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)'],
#  'DP02_0058E': ['Estimate!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school'],
#  'DP02_0058M': ['Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school'],
#  'DP02_0058PE': ['Percent!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school'],
#  'DP02_0058PM': ['Percent Margin of Error!!SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school'],
#  'DP02_0059E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over'],
#  'DP02_0059M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over'],
#  'DP02_0059PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over'],
#  'DP02_0059PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over'],
#  'DP02_0060E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade'],
#  'DP02_0060M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade'],
#  'DP02_0060PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade'],
#  'DP02_0060PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than 9th grade'],
#  'DP02_0061E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma'],
#  'DP02_0061M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma'],
#  'DP02_0061PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma'],
#  'DP02_0061PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!9th to 12th grade, no diploma'],
#  'DP02_0062E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)'],
#  'DP02_0062M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)'],
#  'DP02_0062PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)'],
#  'DP02_0062PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)'],
#  'DP02_0063E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree'],
#  'DP02_0063M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree'],
#  'DP02_0063PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree'],
#  'DP02_0063PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college, no degree'],
#  'DP02_0064E': ["Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree"],
#  'DP02_0064M': ["Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree"],
#  'DP02_0064PE': ["Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree"],
#  'DP02_0064PM': ["Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Associate's degree"],
#  'DP02_0065E': ["Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree"],
#  'DP02_0065M': ["Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree"],
#  'DP02_0065PE': ["Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree"],
#  'DP02_0065PM': ["Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree"],
#  'DP02_0066E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree'],
#  'DP02_0066M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree'],
#  'DP02_0066PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree'],
#  'DP02_0066PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Graduate or professional degree'],
#  'DP02_0067E': ['Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher'],
#  'DP02_0067M': ['Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher'],
#  'DP02_0067PE': ['Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher'],
#  'DP02_0067PM': ['Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher'],
#  'DP02_0068E': ["Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher"],
#  'DP02_0068M': ["Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher"],
#  'DP02_0068PE': ["Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher"],
#  'DP02_0068PM': ["Percent Margin of Error!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher"],
#  'DP02_0069E': ['Estimate!!VETERAN STATUS!!Civilian population 18 years and over'],
#  'DP02_0069M': ['Margin of Error!!VETERAN STATUS!!Civilian population 18 years and over'],
#  'DP02_0069PE': ['Percent!!VETERAN STATUS!!Civilian population 18 years and over'],
#  'DP02_0069PM': ['Percent Margin of Error!!VETERAN STATUS!!Civilian population 18 years and over'],
#  'DP02_0070E': ['Estimate!!VETERAN STATUS!!Civilian population 18 years and over!!Civilian veterans'],
#  'DP02_0070M': ['Margin of Error!!VETERAN STATUS!!Civilian population 18 years and over!!Civilian veterans'],
#  'DP02_0070PE': ['Percent!!VETERAN STATUS!!Civilian population 18 years and over!!Civilian veterans'],
#  'DP02_0070PM': ['Percent Margin of Error!!VETERAN STATUS!!Civilian population 18 years and over!!Civilian veterans'],
#  'DP02_0071E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population'],
#  'DP02_0071M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population'],
#  'DP02_0071PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population'],
#  'DP02_0071PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population'],
#  'DP02_0072E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population!!With a disability'],
#  'DP02_0072M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population!!With a disability'],
#  'DP02_0072PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population!!With a disability'],
#  'DP02_0072PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Total Civilian Noninstitutionalized Population!!With a disability'],
#  'DP02_0073E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years'],
#  'DP02_0073M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years'],
#  'DP02_0073PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years'],
#  'DP02_0073PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years'],
#  'DP02_0074E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability'],
#  'DP02_0074M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability'],
#  'DP02_0074PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability'],
#  'DP02_0074PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!Under 18 years!!With a disability'],
#  'DP02_0075E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years'],
#  'DP02_0075M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years'],
#  'DP02_0075PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years'],
#  'DP02_0075PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years'],
#  'DP02_0076E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability'],
#  'DP02_0076M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability'],
#  'DP02_0076PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability'],
#  'DP02_0076PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!18 to 64 years!!With a disability'],
#  'DP02_0077E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over'],
#  'DP02_0077M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over'],
#  'DP02_0077PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over'],
#  'DP02_0077PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over'],
#  'DP02_0078E': ['Estimate!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over!!With a disability'],
#  'DP02_0078M': ['Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over!!With a disability'],
#  'DP02_0078PE': ['Percent!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over!!With a disability'],
#  'DP02_0078PM': ['Percent Margin of Error!!DISABILITY STATUS OF THE CIVILIAN NONINSTITUTIONALIZED POPULATION!!65 years and over!!With a disability'],
#  'DP02_0079E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over'],
#  'DP02_0079M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over'],
#  'DP02_0079PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over'],
#  'DP02_0079PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over'],
#  'DP02_0080E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house'],
#  'DP02_0080M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house'],
#  'DP02_0080PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house'],
#  'DP02_0080PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Same house'],
#  'DP02_0081E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.'],
#  'DP02_0081M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.'],
#  'DP02_0081PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.'],
#  'DP02_0081PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.'],
#  'DP02_0082E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Same county'],
#  'DP02_0082M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Same county'],
#  'DP02_0082PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Same county'],
#  'DP02_0082PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Same county'],
#  'DP02_0083E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county'],
#  'DP02_0083M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county'],
#  'DP02_0083PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county'],
#  'DP02_0083PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county'],
#  'DP02_0084E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Same state'],
#  'DP02_0084M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Same state'],
#  'DP02_0084PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Same state'],
#  'DP02_0084PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Same state'],
#  'DP02_0085E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Different state'],
#  'DP02_0085M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Different state'],
#  'DP02_0085PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Different state'],
#  'DP02_0085PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Different house in the U.S.!!Different county!!Different state'],
#  'DP02_0086E': ['Estimate!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Abroad'],
#  'DP02_0086M': ['Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Abroad'],
#  'DP02_0086PE': ['Percent!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Abroad'],
#  'DP02_0086PM': ['Percent Margin of Error!!RESIDENCE 1 YEAR AGO!!Population 1 year and over!!Abroad'],
#  'DP02_0087E': ['Estimate!!PLACE OF BIRTH!!Total population'],
#  'DP02_0087M': ['Margin of Error!!PLACE OF BIRTH!!Total population'],
#  'DP02_0087PE': ['Percent!!PLACE OF BIRTH!!Total population'],
#  'DP02_0087PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population'],
#  'DP02_0088E': ['Estimate!!PLACE OF BIRTH!!Total population!!Native'],
#  'DP02_0088M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Native'],
#  'DP02_0088PE': ['Percent!!PLACE OF BIRTH!!Total population!!Native'],
#  'DP02_0088PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native'],
#  'DP02_0089E': ['Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in United States'],
#  'DP02_0089M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States'],
#  'DP02_0089PE': ['Percent!!PLACE OF BIRTH!!Total population!!Native!!Born in United States'],
#  'DP02_0089PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States'],
#  'DP02_0090E': ['Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence'],
#  'DP02_0090M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence'],
#  'DP02_0090PE': ['Percent!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence'],
#  'DP02_0090PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!State of residence'],
#  'DP02_0091E': ['Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state'],
#  'DP02_0091M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state'],
#  'DP02_0091PE': ['Percent!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state'],
#  'DP02_0091PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in United States!!Different state'],
#  'DP02_0092E': ['Estimate!!PLACE OF BIRTH!!Total population!!Native!!Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)'],
#  'DP02_0092M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)'],
#  'DP02_0092PE': ['Percent!!PLACE OF BIRTH!!Total population!!Native!!Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)'],
#  'DP02_0092PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Native!!Born in Puerto Rico, U.S. Island areas, or born abroad to American parent(s)'],
#  'DP02_0093E': ['Estimate!!PLACE OF BIRTH!!Total population!!Foreign born'],
#  'DP02_0093M': ['Margin of Error!!PLACE OF BIRTH!!Total population!!Foreign born'],
#  'DP02_0093PE': ['Percent!!PLACE OF BIRTH!!Total population!!Foreign born'],
#  'DP02_0093PM': ['Percent Margin of Error!!PLACE OF BIRTH!!Total population!!Foreign born'],
#  'DP02_0094E': ['Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population'],
#  'DP02_0094M': ['Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population'],
#  'DP02_0094PE': ['Percent!!U.S. CITIZENSHIP STATUS!!Foreign-born population'],
#  'DP02_0094PM': ['Percent Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population'],
#  'DP02_0095E': ['Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen'],
#  'DP02_0095M': ['Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen'],
#  'DP02_0095PE': ['Percent!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen'],
#  'DP02_0095PM': ['Percent Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Naturalized U.S. citizen'],
#  'DP02_0096E': ['Estimate!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen'],
#  'DP02_0096M': ['Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen'],
#  'DP02_0096PE': ['Percent!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen'],
#  'DP02_0096PM': ['Percent Margin of Error!!U.S. CITIZENSHIP STATUS!!Foreign-born population!!Not a U.S. citizen'],
#  'DP02_0097E': ['Estimate!!YEAR OF ENTRY!!Population born outside the United States'],
#  'DP02_0097M': ['Margin of Error!!YEAR OF ENTRY!!Population born outside the United States'],
#  'DP02_0097PE': ['Percent!!YEAR OF ENTRY!!Population born outside the United States'],
#  'DP02_0097PM': ['Percent Margin of Error!!YEAR OF ENTRY!!Population born outside the United States'],
#  'DP02_0098E': ['Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Native'],
#  'DP02_0098M': ['Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native'],
#  'DP02_0098PE': ['Percent!!YEAR OF ENTRY!!Population born outside the United States!!Native'],
#  'DP02_0098PM': ['Percent Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native'],
#  'DP02_0099E': ['Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later'],
#  'DP02_0099M': ['Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later'],
#  'DP02_0099PE': ['Percent!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later'],
#  'DP02_0099PM': ['Percent Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered 2010 or later'],
#  'DP02_0100E': ['Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010'],
#  'DP02_0100M': ['Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010'],
#  'DP02_0100PE': ['Percent!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010'],
#  'DP02_0100PM': ['Percent Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Native!!Entered before 2010'],
#  'DP02_0101E': ['Estimate!!YEAR OF ENTRY!!Population born outside the United States!!Foreign born'],
#  'DP02_0101M': ['Margin of Error!!YEAR OF ENTRY!!Population born outside the United States!!Foreign born'],
# ...
#  'DP02_0110M': ['Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Northern America'],
#  'DP02_0110PE': ['Percent!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Northern America'],
#  'DP02_0110PM': ['Percent Margin of Error!!WORLD REGION OF BIRTH OF FOREIGN BORN!!Foreign-born population, excluding population born at sea!!Northern America'],
#  'DP02_0111E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over'],
#  'DP02_0111M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over'],
#  'DP02_0111PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over'],
#  'DP02_0111PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over'],
#  'DP02_0112E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!English only'],
#  'DP02_0112M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!English only'],
#  'DP02_0112PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!English only'],
#  'DP02_0112PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!English only'],
#  'DP02_0113E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English'],
#  'DP02_0113M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English'],
#  'DP02_0113PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English'],
#  'DP02_0113PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English'],
#  'DP02_0114E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English!!Speak English less than very well""'],
#  'DP02_0114M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English!!Speak English less than very well""'],
#  'DP02_0114PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English!!Speak English less than very well""'],
#  'DP02_0114PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Language other than English!!Speak English less than very well""'],
#  'DP02_0115E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish'],
#  'DP02_0115M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish'],
#  'DP02_0115PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish'],
#  'DP02_0115PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish'],
#  'DP02_0116E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than very well""'],
#  'DP02_0116M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than very well""'],
#  'DP02_0116PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than very well""'],
#  'DP02_0116PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Spanish!!Speak English less than very well""'],
#  'DP02_0117E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages'],
#  'DP02_0117M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages'],
#  'DP02_0117PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages'],
#  'DP02_0117PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages'],
#  'DP02_0118E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than very well""'],
#  'DP02_0118M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than very well""'],
#  'DP02_0118PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than very well""'],
#  'DP02_0118PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other Indo-European languages!!Speak English less than very well""'],
#  'DP02_0119E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages'],
#  'DP02_0119M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages'],
#  'DP02_0119PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages'],
#  'DP02_0119PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages'],
#  'DP02_0120E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than very well""'],
#  'DP02_0120M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than very well""'],
#  'DP02_0120PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than very well""'],
#  'DP02_0120PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Asian and Pacific Islander languages!!Speak English less than very well""'],
#  'DP02_0121E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages'],
#  'DP02_0121M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages'],
#  'DP02_0121PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages'],
#  'DP02_0121PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages'],
#  'DP02_0122E': ['Estimate!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than very well""'],
#  'DP02_0122M': ['Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than very well""'],
#  'DP02_0122PE': ['Percent!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than very well""'],
#  'DP02_0122PM': ['Percent Margin of Error!!LANGUAGE SPOKEN AT HOME!!Population 5 years and over!!Other languages!!Speak English less than very well""'],
#  'DP02_0123E': ['Estimate!!ANCESTRY!!Total population'],
#  'DP02_0123M': ['Margin of Error!!ANCESTRY!!Total population'],
#  'DP02_0123PE': ['Percent!!ANCESTRY!!Total population'],
#  'DP02_0123PM': ['Percent Margin of Error!!ANCESTRY!!Total population'],
#  'DP02_0124E': ['Estimate!!ANCESTRY!!Total population!!American'],
#  'DP02_0124M': ['Margin of Error!!ANCESTRY!!Total population!!American'],
#  'DP02_0124PE': ['Percent!!ANCESTRY!!Total population!!American'],
#  'DP02_0124PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!American'],
#  'DP02_0125E': ['Estimate!!ANCESTRY!!Total population!!Arab'],
#  'DP02_0125M': ['Margin of Error!!ANCESTRY!!Total population!!Arab'],
#  'DP02_0125PE': ['Percent!!ANCESTRY!!Total population!!Arab'],
#  'DP02_0125PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Arab'],
#  'DP02_0126E': ['Estimate!!ANCESTRY!!Total population!!Czech'],
#  'DP02_0126M': ['Margin of Error!!ANCESTRY!!Total population!!Czech'],
#  'DP02_0126PE': ['Percent!!ANCESTRY!!Total population!!Czech'],
#  'DP02_0126PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Czech'],
#  'DP02_0127E': ['Estimate!!ANCESTRY!!Total population!!Danish'],
#  'DP02_0127M': ['Margin of Error!!ANCESTRY!!Total population!!Danish'],
#  'DP02_0127PE': ['Percent!!ANCESTRY!!Total population!!Danish'],
#  'DP02_0127PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Danish'],
#  'DP02_0128E': ['Estimate!!ANCESTRY!!Total population!!Dutch'],
#  'DP02_0128M': ['Margin of Error!!ANCESTRY!!Total population!!Dutch'],
#  'DP02_0128PE': ['Percent!!ANCESTRY!!Total population!!Dutch'],
#  'DP02_0128PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Dutch'],
#  'DP02_0129E': ['Estimate!!ANCESTRY!!Total population!!English'],
#  'DP02_0129M': ['Margin of Error!!ANCESTRY!!Total population!!English'],
#  'DP02_0129PE': ['Percent!!ANCESTRY!!Total population!!English'],
#  'DP02_0129PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!English'],
#  'DP02_0130E': ['Estimate!!ANCESTRY!!Total population!!French (except Basque)'],
#  'DP02_0130M': ['Margin of Error!!ANCESTRY!!Total population!!French (except Basque)'],
#  'DP02_0130PE': ['Percent!!ANCESTRY!!Total population!!French (except Basque)'],
#  'DP02_0130PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!French (except Basque)'],
#  'DP02_0131E': ['Estimate!!ANCESTRY!!Total population!!French Canadian'],
#  'DP02_0131M': ['Margin of Error!!ANCESTRY!!Total population!!French Canadian'],
#  'DP02_0131PE': ['Percent!!ANCESTRY!!Total population!!French Canadian'],
#  'DP02_0131PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!French Canadian'],
#  'DP02_0132E': ['Estimate!!ANCESTRY!!Total population!!German'],
#  'DP02_0132M': ['Margin of Error!!ANCESTRY!!Total population!!German'],
#  'DP02_0132PE': ['Percent!!ANCESTRY!!Total population!!German'],
#  'DP02_0132PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!German'],
#  'DP02_0133E': ['Estimate!!ANCESTRY!!Total population!!Greek'],
#  'DP02_0133M': ['Margin of Error!!ANCESTRY!!Total population!!Greek'],
#  'DP02_0133PE': ['Percent!!ANCESTRY!!Total population!!Greek'],
#  'DP02_0133PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Greek'],
#  'DP02_0134E': ['Estimate!!ANCESTRY!!Total population!!Hungarian'],
#  'DP02_0134M': ['Margin of Error!!ANCESTRY!!Total population!!Hungarian'],
#  'DP02_0134PE': ['Percent!!ANCESTRY!!Total population!!Hungarian'],
#  'DP02_0134PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Hungarian'],
#  'DP02_0135E': ['Estimate!!ANCESTRY!!Total population!!Irish'],
#  'DP02_0135M': ['Margin of Error!!ANCESTRY!!Total population!!Irish'],
#  'DP02_0135PE': ['Percent!!ANCESTRY!!Total population!!Irish'],
#  'DP02_0135PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Irish'],
#  'DP02_0136E': ['Estimate!!ANCESTRY!!Total population!!Italian'],
#  'DP02_0136M': ['Margin of Error!!ANCESTRY!!Total population!!Italian'],
#  'DP02_0136PE': ['Percent!!ANCESTRY!!Total population!!Italian'],
#  'DP02_0136PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Italian'],
#  'DP02_0137E': ['Estimate!!ANCESTRY!!Total population!!Lithuanian'],
#  'DP02_0137M': ['Margin of Error!!ANCESTRY!!Total population!!Lithuanian'],
#  'DP02_0137PE': ['Percent!!ANCESTRY!!Total population!!Lithuanian'],
#  'DP02_0137PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Lithuanian'],
#  'DP02_0138E': ['Estimate!!ANCESTRY!!Total population!!Norwegian'],
#  'DP02_0138M': ['Margin of Error!!ANCESTRY!!Total population!!Norwegian'],
#  'DP02_0138PE': ['Percent!!ANCESTRY!!Total population!!Norwegian'],
#  'DP02_0138PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Norwegian'],
#  'DP02_0139E': ['Estimate!!ANCESTRY!!Total population!!Polish'],
#  'DP02_0139M': ['Margin of Error!!ANCESTRY!!Total population!!Polish'],
#  'DP02_0139PE': ['Percent!!ANCESTRY!!Total population!!Polish'],
#  'DP02_0139PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Polish'],
#  'DP02_0140E': ['Estimate!!ANCESTRY!!Total population!!Portuguese'],
#  'DP02_0140M': ['Margin of Error!!ANCESTRY!!Total population!!Portuguese'],
#  'DP02_0140PE': ['Percent!!ANCESTRY!!Total population!!Portuguese'],
#  'DP02_0140PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Portuguese'],
#  'DP02_0141E': ['Estimate!!ANCESTRY!!Total population!!Russian'],
#  'DP02_0141M': ['Margin of Error!!ANCESTRY!!Total population!!Russian'],
#  'DP02_0141PE': ['Percent!!ANCESTRY!!Total population!!Russian'],
#  'DP02_0141PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Russian'],
#  'DP02_0142E': ['Estimate!!ANCESTRY!!Total population!!Scotch-Irish'],
#  'DP02_0142M': ['Margin of Error!!ANCESTRY!!Total population!!Scotch-Irish'],
#  'DP02_0142PE': ['Percent!!ANCESTRY!!Total population!!Scotch-Irish'],
#  'DP02_0142PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Scotch-Irish'],
#  'DP02_0143E': ['Estimate!!ANCESTRY!!Total population!!Scottish'],
#  'DP02_0143M': ['Margin of Error!!ANCESTRY!!Total population!!Scottish'],
#  'DP02_0143PE': ['Percent!!ANCESTRY!!Total population!!Scottish'],
#  'DP02_0143PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Scottish'],
#  'DP02_0144E': ['Estimate!!ANCESTRY!!Total population!!Slovak'],
#  'DP02_0144M': ['Margin of Error!!ANCESTRY!!Total population!!Slovak'],
#  'DP02_0144PE': ['Percent!!ANCESTRY!!Total population!!Slovak'],
#  'DP02_0144PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Slovak'],
#  'DP02_0145E': ['Estimate!!ANCESTRY!!Total population!!Subsaharan African'],
#  'DP02_0145M': ['Margin of Error!!ANCESTRY!!Total population!!Subsaharan African'],
#  'DP02_0145PE': ['Percent!!ANCESTRY!!Total population!!Subsaharan African'],
#  'DP02_0145PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Subsaharan African'],
#  'DP02_0146E': ['Estimate!!ANCESTRY!!Total population!!Swedish'],
#  'DP02_0146M': ['Margin of Error!!ANCESTRY!!Total population!!Swedish'],
#  'DP02_0146PE': ['Percent!!ANCESTRY!!Total population!!Swedish'],
#  'DP02_0146PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Swedish'],
#  'DP02_0147E': ['Estimate!!ANCESTRY!!Total population!!Swiss'],
#  'DP02_0147M': ['Margin of Error!!ANCESTRY!!Total population!!Swiss'],
#  'DP02_0147PE': ['Percent!!ANCESTRY!!Total population!!Swiss'],
#  'DP02_0147PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Swiss'],
#  'DP02_0148E': ['Estimate!!ANCESTRY!!Total population!!Ukrainian'],
#  'DP02_0148M': ['Margin of Error!!ANCESTRY!!Total population!!Ukrainian'],
#  'DP02_0148PE': ['Percent!!ANCESTRY!!Total population!!Ukrainian'],
#  'DP02_0148PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Ukrainian'],
#  'DP02_0149E': ['Estimate!!ANCESTRY!!Total population!!Welsh'],
#  'DP02_0149M': ['Margin of Error!!ANCESTRY!!Total population!!Welsh'],
#  'DP02_0149PE': ['Percent!!ANCESTRY!!Total population!!Welsh'],
#  'DP02_0149PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!Welsh'],
#  'DP02_0150E': ['Estimate!!ANCESTRY!!Total population!!West Indian (excluding Hispanic origin groups)'],
#  'DP02_0150M': ['Margin of Error!!ANCESTRY!!Total population!!West Indian (excluding Hispanic origin groups)'],
#  'DP02_0150PE': ['Percent!!ANCESTRY!!Total population!!West Indian (excluding Hispanic origin groups)'],
#  'DP02_0150PM': ['Percent Margin of Error!!ANCESTRY!!Total population!!West Indian (excluding Hispanic origin groups)'],
#  'DP02_0151E': ['Estimate!!COMPUTERS AND INTERNET USE!!Total households'],
#  'DP02_0151M': ['Margin of Error!!COMPUTERS AND INTERNET USE!!Total households'],
#  'DP02_0151PE': ['Percent!!COMPUTERS AND INTERNET USE!!Total households'],
#  'DP02_0151PM': ['Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households'],
#  'DP02_0152E': ['Estimate!!COMPUTERS AND INTERNET USE!!Total households!!With a computer'],
#  'DP02_0152M': ['Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a computer'],
#  'DP02_0152PE': ['Percent!!COMPUTERS AND INTERNET USE!!Total households!!With a computer'],
#  'DP02_0152PM': ['Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a computer'],
#  'DP02_0153E': ['Estimate!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription'],
#  'DP02_0153M': ['Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription'],
#  'DP02_0153PE': ['Percent!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription'],
#  'DP02_0153PM': ['Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription']}

# %% [markdown]
# This is a better visual reference.
#
# *We could remove the first entry (del metadata['NAME']) and break the string descriptions out of their lists. Since we would not gain much-if-anything for our trouble, we will leave the dictionary as it is.*

# %% [markdown]
# ## Helper Functions

# %%
# loading python's `autoreload`, to update any external module changes
# %load_ext autoreload

# turning-on `autoreload`
# %autoreload 2

# %%
# verifying the current working directory
os.getcwd()
# Out:
# 'C:\\Users\\jamel\\myprojects\\acs-api\\notebooks'

# %%
# moving to the parent directory
os.chdir('..')

# verifying the current working directory
os.getcwd()
# Out:
# 'C:\\Users\\jamel\\myprojects\\acs-api'

# %% [markdown]
# ### Serialization

# %% [markdown]
# We will use the `pickle` serialization format to store objects for future use.

# %%
# importing the "helpers folder and contained modules as a package"
from helpers import *

# %% [markdown]
# Within `helpers` is the `helpers_func` package, which includes the custom `save_pickle`/`read_pickle` serialization/de-serialization modules.

# %%
# serializing the data dictionary
save_pickle(metadata_dict, "metadata-dict")

# serializing the list of broadband variables
save_pickle(broadband_vars, "broadband-vars")
# Out:
# --------------- PICKLING metadata-dict -------------------------
# Saved as  metadata-dict.pkl
#
# --------------- PICKLING broadband-vars -------------------------
# Saved as  broadband-vars.pkl

# %%
# # -----uncomment cell to test-----
# # test deleting the variable
# del broadband_vars

# # attempting to view the deleted variable
# print("Result of attempting to print variable after deletion:\n")
# broadband_vars

# %%
# # -----uncomment cell to test-----
# print("Result of attempting to view the object after restoration:\n")

# # restoring the data dictionary from the serialized file
# broadband_vars = read_pickle("pickles/broadband-vars.pkl")
# broadband_vars

# %% [markdown]
# # Scrub

# %% [markdown]
# # Explore

# %% [markdown]
# ## Notebook Summary

# %% [markdown]
# Continue to "2-api-data" notebook.
